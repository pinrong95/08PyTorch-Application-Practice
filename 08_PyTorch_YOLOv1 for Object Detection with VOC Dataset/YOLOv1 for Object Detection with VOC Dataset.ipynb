# %% [markdown]
# Please download all the necessary files from the following link:
#
# ~~https://drive.google.com/open?id=1XTjVnbUzdBYsI99kd8TYZSZYU4W1K7hd~~
#
# Don't use the above link (2021/08 revision).
#
# The files required by this colab file and can be run correctly is the following link:
# ~~https://drive.google.com/file/d/1JDI9l0YYiaW_U3UEuoMeMJ9Mloba4OJ5/view?usp=sharing~~
#
# However, because uploading extracted files will take too much time, from 2022/5/01, this script is modified to download the zip files, unzip them on (1) this tempariry space or (2) "your google drive"!
#
# As of 2023/05/25, there is an unknown issue which will cause the following error message:
#
# ```
# File "/usr/local/lib/python3.10/dist-packages/PIL/Image.py", line 1680, in point
#     return self._new(self.im.point(lut, mode))
# TypeError: 'float' object cannot be interpreted as an integer
# ```
#
# However, it is solved by modifying the function-distort_image(), Everything works now.

# %%
# update gdown for compatibility issue. 2022/12/12
# !pip install --upgrade gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2024.12.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
from google.colab import drive
import os

# The flag to determine where to put the downloaded files.
# True: zip file will be downloaded to this space
# False:
# manually download file folder from https://drive.google.com/file/d/14KWN84l4O4jSaiFMGnjvw7oauUN7YOn1/view?usp=sharing
# unzip it and upload the folder-YOLO_data_model to the 1st level of your google drive which is actually "/content/drive/My Drive/"
In_this_space_flag = True

#上傳至暫存資料夾
if In_this_space_flag == True and os.path.isdir("/content/YOLO_data_model/") == False:
# 1 do everything in this temporary space
  #print('here')
  os.system("gdown https://drive.google.com/uc?id=14KWN84l4O4jSaiFMGnjvw7oauUN7YOn1") #下載
  os.system("unzip YOLO_data_model.zip") #壓縮檔 解壓縮
  os.remove("YOLO_data_model.zip") #刪除壓縮檔
elif In_this_space_flag == False: # and os.path.isdir("/content/drive/My Drive/YOLO_data_model/") == True:
  drive.mount('/content/drive')
  assert os.path.isdir("/content/drive/My Drive/YOLO_data_model/") == True

# %%
#from google.colab import drive
#drive.mount("/content/drive", force_remount=True)
#drive.mount('/content/gdrive')

from google.colab.patches import cv2_imshow

import cv2 as cv
#至暫存的資料夾中讀取檔案，確認使用沒問題

if In_this_space_flag == True:
  ## version 1: download file 於暫存空間抓取檔案
  # data folder
  # 資料夾路徑
  VOC_root_dir = "/content/YOLO_data_model/"
else:
  ## version 2: download file 於drive抓取檔案
  # data folder
  VOC_root_dir = "/content/drive/My Drive/YOLO_data_model/"

# Let's try to shown an image for making sure that all the data under the folder-YOLO_data_model is accessible.
img_path = VOC_root_dir + "VOCdevkit/VOC2007/JPEGImages/000001.jpg"
print(img_path)

img1_rgb = cv.imread(img_path)

cv2_imshow(img1_rgb)

print(img1_rgb.size)
# Out:
# /content/YOLO_data_model/VOCdevkit/VOC2007/JPEGImages/000001.jpg
# <PIL.Image.Image image mode=RGB size=353x500>
# 529500

# %%
import torch
import torch.optim as optim
from tqdm import tqdm
import numpy as np
from torchvision import transforms
import time
import os
import pickle

classes = ["aeroplane", "bicycle", "bird", "boat", "bottle", "bus", "car", "cat",
           "chair", "cow", "diningtable", "dog", "horse", "motorbike", "person",
           "pottedplant", "sheep", "sofa", "train", "tvmonitor"]

bbox_num = 2
box_scale = 7
lr = 0.1e-2 # do remember that this is the initial learning rate; multifixed learning rate is manually written in the training loop


# Do remember that GT of training and testing data are given in two separate ways.
# In VOC2007_trainval.txt, every training jpg file and its corresponding GT (under /content/drive/MyDrive/YOLO_data_model/VOCdevkit/VOC2007/Label) are listed line-by-line.
# So did VOC2007_test.txt. However, in test_result(), although the same data loader (VOCDatasets()) is used, only image file names are used for performing image inference.
# The inference results are stored under detection_result_txt_folder = "/content/drive/MyDrive/YOLO_data_model/detection_temp_folder/".
# Then, mAP is estimated by reading the testing file list-test.txt under "/content/drive/MyDrive/YOLO_data_model/VOCdevkit/VOC2007/ImageSets/Main/"
# and the filenames (no extension) listed line-by-line will be used to read GT (stored in xml files) under "/content/drive/MyDrive/YOLO_data_model/VOCdevkit/VOC2007/Annotation/".
# The GT loaded in terms of pkls for mAP estimation is put under GT_temp_folder = "/content/drive/MyDrive/YOLO_data_model/GT_temp/".




# training image list
train_image_list = VOC_root_dir + "VOC2007_train.txt"
# tesing image list
eval_image_list = VOC_root_dir + "VOC2007_test.txt"

# folder for training or trained models
# 已訓練好的模型路徑,這是模型訓練完成後的成果，通常包含了具體的權重、結構及優化參數
model_path = VOC_root_dir + "trained_YOLO_model/"
# pretrained model (darknet19)
# 預訓練模型是以某些大型資料集（例如 darknet19）訓練出來的模型，用來提供初始權重
# darknet19_448.conv.23 表示一個以 Darknet19 模型訓練的特定層數的權重檔案（前 23 層）
pretrain_path = VOC_root_dir + "darknet19_448.conv.23"


# folder for detection result to be used for estimating mAP
# 這個資料夾用來存放模型的檢測結果，每個檔案對應一張測試影像的預測結果。
# 這些結果會與標註檔案（ground truth）進行比較，來計算 mAP。
detection_result_txt_folder = VOC_root_dir + "detection_temp_folder/"
# folder to store temp GT data (pkl files)
# 這個資料夾用來暫存真實標註資料（Ground Truth），通常以 .pkl 文件儲存。
GT_temp_folder = VOC_root_dir + "GT_temp/"
# log file for mAP estimation corresponding to each epoch
# 這是用來記錄模型評估過程的日誌檔案（.txt 格式）。
savelog_filename = VOC_root_dir + "savelog.txt"


#model_save_iter = 1  # epochs
epochs_start = 1 #0
epochs_end = 11 #150
batch_size =  12 #24 originally # the size depends on the RAM of GPU
cls_num = len(classes)

'''
下方YOLO的程式碼定義中
描述到，當epochs_start=1，
就使用 pretrain model(darknet19)
其他則自行去訓練YOLO 模型
'''


# 這段程式碼設定了資料增強（data augmentation）的參數，用於訓練過程中對影像進行隨機變化，幫助模型提升泛化能力。
## data augmentation
jitter = 0.2 # 控制影像的隨機縮放和偏移（平移）
hue = 0.1  # 控制影像顏色的色調（hue）變化。
saturation = 1.5 # 控制影像飽和度的隨機變化。
exposure = 1.5 # 控制影像的曝光度（亮度）變化。
'''
為什麼需要資料增強？
提升模型的泛化能力：

增強可以模擬各種場景（例如不同光線條件、顏色偏移等），幫助模型更好地適應實際應用中的多樣性。
防止過擬合：

透過增強產生更多變化的影像，避免模型只學會記住特定樣本。
增加數據集的多樣性：

在資料不足的情況下，資料增強是非常有效的策略。
'''

# weightings of loss
# 這是**座標損失（coordinate loss）**的加權係數，用於加強對邊界框位置（x, y, width, height）預測的懲罰。
l_coord = 5
# 這是**背景損失（no-object loss）**的加權係數，用於降低對背景區域的置信度損失的影響。
l_noobj = 0.5
'''
為什麼需要這些權重？
YOLO 的損失函數由三部分組成：

座標損失（Coordinate Loss）：物體邊界框的預測與真實值之間的誤差。
置信度損失（Confidence Loss）：
有物體的置信度損失（object confidence loss）：對有物體區域，計算模型預測的置信度與真實值的誤差。
無物體的置信度損失（no-object confidence loss）：對無物體區域，計算背景的置信度誤差。
分類損失（Class Loss）：物體類別的預測與真實標籤之間的誤差。
'''

YOLO_cfg = {
    'ceils_size':7,
    'class_num':len(classes),
    'box_num':2,
    'image_size':[448,448]
}

# %%
# Model definition

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch.autograd import Variable

layer_configs = [
        # Unit1 (2)
        (32, 3, True),
        (64, 3, True),
        # Unit2 (3)
        (128, 3, False),
        (64, 1, False),
        (128, 3, True),
        # Unit3 (3)
        (256, 3, False),
        (128, 1, False),
        (256, 3, True),
        # Unit4 (5)
        (512, 3, False),
        (256, 1, False),
        (512, 3, False),
        (256, 1, False),
        (512, 3, True),
        # Unit5 (5)
        (1024, 3, False),
        (512, 1, False),
        (1024, 3, False),
        (512, 1, False),
        (1024, 3, False),
]

# 繼承 (Inheritance)：conv_block 繼承了 nn.Module，因此它具有 nn.Module 所有的屬性和功能。
# nn.Module 是 PyTorch 中用來定義神經網絡模型的基類。所有的神經網絡結構（例如層、模塊等）通常都會繼承這個類別。nn.Module 提供了很多用來管理模型、參數和計算邏輯的功能。
'''
1.定義網絡層結構：你可以在 __init__ 方法中定義網絡的各個層（例如卷積層、池化層等）。
2.執行前向傳播：在 forward 方法中，定義數據如何流經這些層。
3.管理參數：所有在 nn.Module 中定義的層會自動成為可訓練的參數（weights 和 biases），並能夠輕鬆地保存和加載。
4.支援嵌套結構：你可以將多個子模塊（例如子網絡）嵌套到一個主網絡中，並且它們會自動成為模型的一部分。
'''

class conv_block(nn.Module):

    def __init__(self,inplane,outplane,kernel_size,pool,stride=1):
        # super().__init__()，調用父類的初始化函數，
        super(conv_block, self).__init__()

        pad = 1 if kernel_size == 3 else 0
        # 通過繼承自 nn.Module 的 nn.Conv2d 類別來創建一個卷積層
        self.conv = nn.Conv2d(inplane, outplane, kernel_size, stride=stride, padding=pad, bias=False)
        self.bn = nn.BatchNorm2d(outplane)
        self.act = nn.LeakyReLU(0.1)
        self.pool = pool #MaxPool2d(2,stride = 2)

    def forward(self,x):

        out = self.conv(x)
        out = self.bn(out)
        out = self.act(out)

        if self.pool:
            out = F.max_pool2d(out,kernel_size=2,stride=2)

        return out


class darknet_19(nn.Module):

    def __init__(self,cls_num = 1000):
        super(darknet_19, self).__init__()
        self.class_num = cls_num
        self.feature = self.make_layers(3,layer_configs)
        # 當這個 darknet_19 類別的實例被創建時，會進行 初始化，並且會自動呼叫 make_layers(self, inplane, cfg) 函數來建立網絡的層。

    # darknet 19的conv layer 架構建立
    def make_layers(self,inplane,cfg):
        layers = []

        for outplane,kernel_size,pool in cfg:
            layers.append(conv_block(inplane,outplane,kernel_size,pool))
            inplane = outplane


        return nn.Sequential(*layers)

    # 從file中讀取權重
    def load_weight(self,weight_file):
        print("Load pretrained models !")

        fp = open(weight_file, 'rb')
        # 用來從二進制文件中直接讀取數據並將其載入為 NumPy 陣列。
        header = np.fromfile(fp, count=4, dtype=np.int32)
        # 用於將 NumPy 陣列轉換為 PyTorch 張量。
        header = torch.from_numpy(header)
        buf = np.fromfile(fp, dtype = np.float32)

        start = 0
        # self.feature 是由 nn.Module（通常是 nn.Sequential）構建的，因此也繼承了 modules() 方法。
        for idx,m in enumerate(self.feature.modules()):
            if isinstance(m, nn.Conv2d):
                conv = m
            if isinstance(m, nn.BatchNorm2d):
                bn = m
                start = load_conv_bn(buf,start,conv,bn)

        assert start == buf.shape[0]

    def forward(self, x):

        output = self.feature(x)

        return output

class YOLO(nn.Module):

    def __init__(self,cls_num,bbox_num = 2,scale_size = 7, pretrained = None):
        super(YOLO, self).__init__()

        self.cls_num = cls_num
        self.feature = darknet_19()
        #self.conv_model = conv_model
        if pretrained is not None :
            self.feature.load_weight(pretrained)


        self.scale_size = scale_size
        self.bbox_num = bbox_num
        self.last_output = (5*self.bbox_num+self.cls_num)

        cx = torch.linspace(0.5 / scale_size, (scale_size-0.5) / scale_size, steps=scale_size).\
            view(-1, scale_size).repeat(scale_size, 1).view(scale_size, scale_size, -1)
        cy = torch.linspace(0.5 / scale_size, (scale_size-0.5) / scale_size, steps=scale_size).\
            view(scale_size, -1).repeat(1, scale_size).view(scale_size, scale_size, -1)
        self.anchor = torch.cat((cx, cy), 2)

        self.local_layer = nn.Sequential()

        self.local_layer.add_module('block_1',conv_block(1024,1024,3,False,2))

        self.local_layer.add_module('block_2',conv_block(1024,1024,3,False,1))

        self.local_layer.add_module('block_3',conv_block(1024,1024,3,False,1))

        self.local_layer.add_module('block_4',conv_block(1024,1024,3,False,1))


        self.reg_layer = nn.Sequential()

        self.reg_layer.add_module('local_layer', nn.Linear(1024*7*7, 4096))
        self.reg_layer.add_module('leaky_local', nn.LeakyReLU(0.1, inplace=True))
        self.reg_layer.add_module('dropout', nn.Dropout(0.5) )
        self.reg_layer.add_module('fc_1', nn.Linear(4096, (5*self.bbox_num+self.cls_num)*self.scale_size*self.scale_size ))

    def forward(self,x):
        B = x.size(0)
        output = self.feature(x)
        output = self.local_layer(output)

        output = output.view(output.data.size(0),-1)

        output = self.reg_layer(output)

        output = output.view(-1,self.bbox_num*5+self.cls_num,self.scale_size,self.scale_size)

        output = output.permute(0,2,3,1).contiguous()

        pred_cls = output[:, :, :, :self.cls_num]
        pred_bbox = torch.cat(
            [output[:, :, :, self.cls_num + 5*j:self.cls_num + 4 + 5*j ] for j in range(self.bbox_num)],
            -1)
        pred_response = torch.cat([output[:, :, :, self.cls_num + 4 + 5*j:self.cls_num + 4+ 5*j +1]
                                   for j in range(self.bbox_num)], -1)
        anchors = self.anchor.repeat((B, 1, 1, 1)).to(pred_bbox.device)
        pred_bbox[:,:,:,0:2] += anchors

        return pred_cls,pred_response,pred_bbox



def load_conv_bn(buf, start, conv_model, bn_model):
    num_w = conv_model.weight.numel()

    num_b = bn_model.bias.numel()
    bn_model.bias.data.copy_(torch.from_numpy(buf[start:start+num_b]));     start = start + num_b
    bn_model.weight.data.copy_(torch.from_numpy(buf[start:start+num_b]));   start = start + num_b
    bn_model.running_mean.copy_(torch.from_numpy(buf[start:start+num_b]));  start = start + num_b
    bn_model.running_var.copy_(torch.from_numpy(buf[start:start+num_b]));   start = start + num_b

    conv_weight = torch.from_numpy(buf[start:start+num_w])
    conv_model.weight.data.copy_(conv_weight.view_as(conv_model.weight)); start = start + num_w
    return start

# %%
 # load pretrained model (Darknet-19) or unfinished trained model
if epochs_start == 1:
    net = YOLO(cls_num, bbox_num, box_scale, pretrained=pretrain_path)
else:
    net = YOLO(cls_num, bbox_num, box_scale)

# 將模型（net）移動到 GPU 上，讓其在 CUDA 支援的顯卡上進行計算。
net.cuda()
net.train()


if epochs_start > 1:
    net.load_state_dict(torch.load(model_path + 'model_.pkl'))

print("load model successfully")
# Out:
# Load pretrained models !
# load model successfully

# %%
#BBox encoder, decoder for the last layer (7*7*30) and Non-Maximal Suppression

def yolo_box_encoder(bs):

    bb_class = np.zeros((YOLO_cfg['ceils_size'], YOLO_cfg['ceils_size'], YOLO_cfg['class_num']))
    bb_response = np.zeros((YOLO_cfg['ceils_size'], YOLO_cfg['ceils_size'], YOLO_cfg['box_num']))
    bb_boxes = np.zeros((YOLO_cfg['ceils_size'], YOLO_cfg['ceils_size'], 4 * YOLO_cfg['box_num']))

    for i in range(bs.shape[0]):

        local_x = int( min(0.99,bs[i,0] + bs[i,2] / 2) * YOLO_cfg['ceils_size'])
        local_y = int( min(0.99,bs[i,1] + bs[i,3] / 2) * YOLO_cfg['ceils_size'])

        for j in range(YOLO_cfg['box_num']):
            bb_response[local_y, local_x, j] = 1

            bb_boxes[local_y, local_x, j * 4 + 0] = (bs[i,0] + bs[i,2] /2)
            bb_boxes[local_y, local_x, j * 4 + 1] = (bs[i,1] + bs[i,3] /2)
            bb_boxes[local_y, local_x, j * 4 + 2] = np.sqrt(bs[i,2])
            bb_boxes[local_y, local_x, j * 4 + 3] = np.sqrt(bs[i,3])

        bb_class[local_y, local_x, int(bs[i,4])] = 1

    bb_boxes = torch.from_numpy(bb_boxes).float()
    bb_class = torch.from_numpy(bb_class).float()
    bb_response = torch.from_numpy(bb_response).float()
    boxes = (bb_class,bb_response,bb_boxes)

    return boxes

def py_cpu_nms(dets, scores, thresh):
    # dets:(m,5)  thresh:scaler
    #print(scores.shape)
    temp_len = 0  # np.max(dets[:,2]) * 0.05

    x1 = dets[:, 0]
    y1 = dets[:, 1]
    x2 = x1 + dets[:, 2]  # dets[:, 2]#
    y2 = y1 + dets[:, 3]  # dets[:, 3]#

    areas = (y2 - y1 + temp_len) * (x2 - x1 + temp_len)

    keep = []

    index = scores.argsort()[::-1][:200]


    while index.size > 0:
        i = index[0]  # every time the first is the biggst, and add it directly
        keep.append(i)

        x11 = np.maximum(x1[i], x1[index[1:]])  # calculate the points of overlap
        y11 = np.maximum(y1[i], y1[index[1:]])
        x22 = np.minimum(x2[i], x2[index[1:]])
        y22 = np.minimum(y2[i], y2[index[1:]])

        w = np.maximum(0, x22 - x11 + temp_len)  # the weights of overlap
        h = np.maximum(0, y22 - y11 + temp_len)  # the height of overlap

        overlaps = w * h
        #assert overlaps.all() >= 0
        ious = overlaps / (areas[i] + areas[index[1:]] - overlaps)

        idx = np.where(ious <= thresh)[0]
        index = index[idx + 1]

    return keep

def yolo_box_decoder(pred,conf_thresh=0.01,nms_thresh=0.5):
    box_scale = YOLO_cfg['ceils_size']
    cls_num = YOLO_cfg['class_num']
    box_num = YOLO_cfg['box_num']

    pred_cls, pred_response, pred_bboxes = pred

    pred_cls = pred_cls.cpu()
    pred_response = pred_response.cpu()
    pred_bboxes = pred_bboxes.cpu()

    prob = pred_response
    max_prob, max_prob_index = prob.max(3)
    boxes = []
    classes = []


    max_prob_index = max_prob_index.permute(1,2,0)
    for B in range(1):
        for cls in range(cls_num):

            cls_prob = (pred_cls[B,:,:,cls]*max_prob[B, :, :]).data

            mask_box = torch.zeros((box_scale,box_scale,box_num))

            mask_box.scatter_(2,max_prob_index,1)
            mask_box = mask_box.unsqueeze(-1)

            mask_box = mask_box.repeat(1,1,1,4).view(box_scale,box_scale,box_num*4)
            mask_box = mask_box.unsqueeze(0).byte()
            mask_box = mask_box.expand_as(pred_bboxes)
            bbox = pred_bboxes[mask_box].data

            bbox = bbox.reshape(-1,4)
            cls_prob = cls_prob.reshape(-1,1)

            a = cls_prob.gt(conf_thresh)
            mask_a = a.expand_as(bbox)

            bbox = bbox[mask_a].reshape(-1,4)
            cls_prob = cls_prob[a].reshape(-1,1)

            if bbox.shape[0] > 0:
                bbox[:,0:2] = bbox[:,0:2] - 0.5*torch.pow(bbox[:,2:4],2)
                bbox[:,2:4] = torch.pow(bbox[:,2:4],2)

                pre_cls_box = bbox.data.numpy()
                pre_cls_score = cls_prob.data.view(-1).numpy()

                keep = py_cpu_nms(pre_cls_box, pre_cls_score, thresh=nms_thresh)
                for conf_keep, loc_keep in zip(pre_cls_score[keep], pre_cls_box[keep]):
                    boxes.append(loc_keep)
                    classes.append([cls,conf_keep])

    boxes = np.array(boxes)
    classes = np.array(classes)

    return boxes,classes

# %%
# data loader and data augmentation

from PIL import Image,ImageEnhance
from torch.utils import data
import random

def distort_image(im, hue, sat, val):
    im = im.convert('HSV')
    cs = list(im.split())
    # cs[1] = cs[1].point(lambda i: i * sat)
    # cs[2] = cs[2].point(lambda i: i * val)

    # def change_hue(x):
    #     x += hue*255
    #     if x > 255:
    #         x -= 255
    #     if x < 0:
    #         x += 255
    #     return x
    cs[1] = cs[1].point(lambda i: int(float(i) * sat))
    cs[2] = cs[2].point(lambda i: int(float(i) * val))

    def change_hue(x):
        x += hue*float(255)
        if x > 255:
            x -= 255
        if x < 0:
            x += 255
        return int(x)
    cs[0] = cs[0].point(change_hue)
    im = Image.merge(im.mode, tuple(cs))

    im = im.convert('RGB')
    return im

def rand_scale(s):
    scale = random.uniform(1, s)
    if(random.randint(1,10000)%2):
        return scale
    return 1./scale

def random_distort_image(im, hue, saturation, exposure):
    dhue = random.uniform(-hue, hue)
    dsat = rand_scale(saturation)
    dexp = rand_scale(exposure)
    #print('----dhue={}'.format(dhue))
    #print('----dsat={}'.format(dsat))
    #print('----dexp={}'.format(dexp))
    res = distort_image(im, dhue, dsat, dexp)
    return res


def data_augmentation(img, shape, jitter, hue, saturation, exposure):
    oh = img.height
    ow = img.width

    dw =int(ow*jitter)
    dh =int(oh*jitter)

    pleft  = random.randint(-dw, dw)
    pright = random.randint(-dw, dw)
    ptop   = random.randint(-dh, dh)
    pbot   = random.randint(-dh,dh)


    swidth =  ow - pleft - pright
    sheight = oh - ptop - pbot


    sx = float(swidth)  / ow
    sy = float(sheight) / oh

    flip = random.randint(1,10000)%2

    cropped = img.crop( (pleft, ptop, pleft + swidth - 1, ptop + sheight - 1))

    dx = (float(pleft)/ow)/sx
    dy = (float(ptop) /oh)/sy


    sized = cropped.resize(shape,Image.NEAREST)
    if flip:
        sized = sized.transpose(Image.FLIP_LEFT_RIGHT)
    img = random_distort_image(sized, hue, saturation, exposure)

    return img, flip, dx,dy,sx,sy

def fill_truth_detection(bs, flip, dx, dy, sx, sy):

    new_bs = []
    #print(bs)
    for i in range(bs.shape[0]):
        x1 = bs[i][0]
        y1 = bs[i][1]
        x2 = bs[i][0] + bs[i][2]
        y2 = bs[i][1] + bs[i][3]

        x1 = min(0.99, max(0, x1 * sx - dx))
        y1 = min(0.99, max(0, y1 * sy - dy))

        x2 = max(0, min(0.999, x2 * sx - dx))
        y2 = max(0, min(0.999, y2 * sy - dy))


        bs[i][0] = x1
        bs[i][1] = y1
        bs[i][2] = x2 - x1
        bs[i][3] = y2 - y1
        bs[i][4] = bs[i][4]
        if flip:
            bs[i][0] =  1 - bs[i][0] - bs[i][2]

        if bs[i][2] > 0 and bs[i][3] > 0:
            new_bs.append([bs[i]])

    new_bs = np.array(new_bs)
    new_bs = np.reshape(new_bs, (-1, 5))

    return new_bs


def norm_bb(b,size):
    x = b[:, 0:1]
    y = b[:, 1:2]

    dw = 1. / size[0]
    dh = 1. / size[1]

    x = (x * dw).clip(0.01, 0.99)
    y = (y * dh).clip(0.01, 0.99)
    w = ((b[:, 2:3] - b[:, 0:1]) * dw).clip(0.01, 0.99)
    h = ((b[:, 3:4] - b[:, 1:2]) * dh).clip(0.01, 0.99)

    return np.concatenate((x, y, w, h, b[:, 4:5]), axis=1)

def load_data_detection(imgpath,labpath ,shape, aug = True, jitter=0.2, hue=0.1, saturation=1.5, exposure=1.5):

    #print('---imgpath={}'.format(imgpath))
    img = Image.open(imgpath).convert('RGB')

    bs = np.loadtxt(labpath,delimiter=',')
    bs = np.reshape(bs, (-1, 5))

    bs = norm_bb(bs,(img.width,img.height))

    # data augmentation is applied only in training phase
    if aug:
        img, flip, dx, dy, sx, sy = data_augmentation(img, shape, jitter, hue, saturation, exposure)
    else:
        flip, dx, dy, sx, sy = False, 0, 0, 1, 1

    #print(dx, dy, sx, sy)
    label = fill_truth_detection(bs, flip, dx, dy, 1./sx, 1./sy)

    return img,label



class VOCDatasets(data.Dataset):
    def __init__(self, transform, list_file, VOC_root_dir, box_encoder = None, train=False):

        self.transform = transform
        self.train = train
        self.label_path = []
        self.image_path = []
        self.box_encoder = box_encoder
        with open(list_file) as f:
            lines = f.readlines()

        self.num_samples = len(lines)

        for line in lines:
            # using "__" instead of "__" because the data path under Google drive is all "/content/drive/MyDrive/...
            # Therefore, the following .split(' ') function would result in error
            # splited = line.strip().split(' ')
            splited = line.strip().split('__')
            self.image_path.append(VOC_root_dir + splited[0])
            self.label_path.append(VOC_root_dir + splited[1])

    def __getitem__(self, idx):

        file_name = self.image_path[idx]
        gt_path = self.label_path[idx]

        #img,bbox = data_augment(file_name,gt_path,self.train)
        #print('--in __getitem__, file_name={}'.format(file_name))
        img, bbox = load_data_detection(file_name, gt_path, [448, 448], self.train)
        #maximum bbox=50

        if self.box_encoder is not None:
            gt = self.box_encoder(bbox)
        else:
            gt = np.zeros((50, 5), dtype=np.float32)
            gt[:len(bbox), :] = bbox
            gt = torch.from_numpy(gt).float()

        img = self.transform(img)*255

        return img,gt

    def __len__(self):
        return self.num_samples

# remember that the following tansform would only accept PIL images as input
transform = transforms.Compose([
    transforms.Resize([448, 448]),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [1, 1, 1])
])


dataset = VOCDatasets(transform, train_image_list, VOC_root_dir, yolo_box_encoder, train=True) # train=true will apply data augmentation

train_loader = data.DataLoader(dataset=dataset,
                              batch_size=batch_size,
                              shuffle=True,
                              num_workers=1)

# %%
# YOLO loss

import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.autograd import Variable

class yolov1_loss(nn.Module):
    def __init__(self, B, l_coord, l_noobj,device='cuda' ,cls_num=20):
        super(yolov1_loss, self).__init__()
        self.B = B # bbox_num
        self.l_coord = l_coord
        self.l_noobj = l_noobj
        self.class_num = cls_num
        self.device = device

    def compute_iou(self, box1, box2):
        '''Compute the intersection over union of two set of boxes, each box is [x1,y1,x2,y2].
        Args:
          box1: (tensor) bounding boxes, sized [N,4].
          box2: (tensor) bounding boxes, sized [M,4].
        Return:
          (tensor) iou, sized [N,M].
        '''

        lt = torch.max(
            box1[:, :2],  # [N,2] -> [N,1,2] -> [N,M,2]
            box2[:, :2],  # [M,2] -> [1,M,2] -> [N,M,2]
        )

        rb = torch.min(
            box1[:, 2:],  # [N,2] -> [N,1,2] -> [N,M,2]
            box2[:, 2:],  # [M,2] -> [1,M,2] -> [N,M,2]
        )

        wh = rb - lt  # [N,M,2]
        wh[wh < 0] = 0  # clip at 0
        inter = wh[:, 0] * wh[:, 1]  # [N,M]

        area1 = (box1[:, 2] - box1[:, 0]) * (box1[:, 3] - box1[:, 1])  # [N,]
        area2 = (box2[:, 2] - box2[:, 0]) * (box2[:, 3] - box2[:, 1])  # [M,]

        iou = inter / (area1 + area2 - inter)
        return iou

    def forward(self,pred,target):
        #print(target)
        pred_cls, pred_response, pred_bboxes = pred
        label_cls, label_response, label_bboxes = target


        pred_cls = pred_cls.to(self.device)
        pred_response =  pred_response.to(self.device)
        pred_bboxes = pred_bboxes.to(self.device)

        label_cls = label_cls.to(self.device)
        label_response =  label_response.to(self.device)
        label_bboxes = label_bboxes.to(self.device)


        batch_size = pred_response.size(0)

        no_obj_mask = (label_response[:, :, :, 0] < 1).unsqueeze(-1).expand_as(label_response)

        obj_response_mask = (label_response[:, :, :, 0] > 0).unsqueeze(-1).expand_as(label_response)

        obj_box_mask = (label_response[:, :, :, 0] > 0).unsqueeze(-1).expand_as(label_bboxes)

        obj_cls_mask = (label_response[:, :, :, 0] > 0).unsqueeze(-1).expand_as(label_cls)

        no_obj_contain_pred = pred_response[no_obj_mask].view(-1)
        no_obj_contain_target = label_response[no_obj_mask].view(-1)


        obj_contain_pred = pred_response[obj_response_mask].view(-1, self.B)

        obj_contain_target = label_response[obj_response_mask].view(-1, self.B)

        # class pred response
        obj_class_pred = pred_cls[obj_cls_mask].view(-1, self.class_num)
        obj_class_target = label_cls[obj_cls_mask].view(-1, self.class_num)

        # box pred response
        obj_loc_pred = pred_bboxes[obj_box_mask].view(-1, self.B * 4)
        obj_loc_target = label_bboxes[obj_box_mask].view(-1, self.B * 4)

        iou = torch.zeros(obj_loc_pred.size(0), self.B)
        iou = Variable(iou)

        for j in range(self.B):
            pred_bb = torch.zeros(obj_loc_pred.size(0), 4)
            pred_bb = Variable(pred_bb)

            target_bb = torch.zeros(obj_loc_pred.size(0), 4)
            target_bb = Variable(target_bb)

            target_bb[:, 0] = obj_loc_target[:, j * 4] - 0.5 * pow(obj_loc_target[:, j * 4 + 2], 2)
            target_bb[:, 1] = obj_loc_target[:, j * 4 + 1] - 0.5 * pow(obj_loc_target[:, j * 4 + 3], 2)
            target_bb[:, 2] = obj_loc_target[:, j * 4] + 0.5 * pow(obj_loc_target[:, j * 4 + 2], 2)
            target_bb[:, 3] = obj_loc_target[:, j * 4 + 1] + 0.5 * pow(obj_loc_target[:, j * 4 + 3], 2)

            pred_bb[:, 0] = obj_loc_pred[:, j * 4] - 0.5 * pow(obj_loc_pred[:, j * 4 + 2], 2)
            pred_bb[:, 1] = obj_loc_pred[:, j * 4 + 1] - 0.5 * pow(obj_loc_pred[:, j * 4 + 3], 2)
            pred_bb[:, 2] = obj_loc_pred[:, j * 4] + 0.5 * pow(obj_loc_pred[:, j * 4 + 2], 2)
            pred_bb[:, 3] = obj_loc_pred[:, j * 4 + 1] + 0.5 * pow(obj_loc_pred[:, j * 4 + 3], 2)

            iou[:, j] = self.compute_iou(target_bb, pred_bb)

        max_iou, max_index = iou.max(1)
        min_iou, _ = iou.min(1)
        max_index = max_index.data.cpu()

        coo_response_mask = torch.ByteTensor(obj_loc_pred.size(0), self.B * 4).to(self.device)

        coo_response_mask.zero_()
        for i in range(obj_loc_pred.size(0)):
            coo_response_mask[i, max_index[i] * 4:max_index[i] * 4 + 4] = 1

        obj_axis_pred = obj_loc_pred[coo_response_mask].view(-1, 4)
        obj_axis_target = obj_loc_target[coo_response_mask].view(-1, 4)

        iou_response_mask = coo_response_mask[:, [i * 4 for i in range(self.B)]]

        obj_response_pred = obj_contain_pred[iou_response_mask].view(-1)
        obj_response_target = obj_contain_target[iou_response_mask].view(-1)

        obj_local_loss = F.mse_loss(obj_axis_pred[:, 0:2], obj_axis_target[:, 0:2], size_average=False) + \
                         F.mse_loss(obj_axis_pred[:, 2:4], obj_axis_target[:, 2:4], size_average=False)
        obj_class_loss = F.mse_loss(obj_class_pred, obj_class_target, size_average=False)


        max_iou = (max_iou.data).to(self.device)
        conf_id = ((1 - max_iou) * self.l_noobj + max_iou).to(self.device)

        conf_id = Variable(conf_id, requires_grad=True)

        obj_contain_loss = F.mse_loss(obj_response_pred, max_iou, size_average=False)

        no_obj_contain_loss = F.mse_loss(no_obj_contain_pred, no_obj_contain_target, size_average=False)

        iou_loss = F.mse_loss(max_iou, obj_response_target, size_average=False)

        loss_all = (self.l_coord * obj_local_loss + obj_class_loss + obj_contain_loss + self.l_noobj * no_obj_contain_loss + iou_loss) / batch_size

        loss_info = {
            'local_loss': self.l_coord * obj_local_loss.data,
            'class_loss': obj_class_loss.data,
            'contain_loss': obj_contain_loss.data,
            'no_contain_loss': self.l_noobj * no_obj_contain_loss,
            'iou_loss': iou_loss,
            'mean_iou': torch.mean(max_iou)
        }

        return loss_all, loss_info

# %%
# optimizer and loss

optimizer = optim.SGD(net.parameters(), lr=lr, momentum=0.9, weight_decay=5e-4)

device='cuda'

loss_detect = yolov1_loss(bbox_num, l_coord, l_noobj, device, cls_num)

# do remind the difference between step & epoch
step = epochs_start * len(train_loader)

best_score = 0
eval_score = 0

# %%
# mAP estimation


import xml.etree.ElementTree as ET
import os
import pickle
import numpy as np
import cv2


def parse_rec(filename):
    """ Parse a PASCAL VOC xml file """
    tree = ET.parse(filename)
    objects = []
    for obj in tree.findall('object'):
        obj_struct = {}
        obj_struct['name'] = obj.find('name').text
        obj_struct['pose'] = obj.find('pose').text
        obj_struct['truncated'] = int(obj.find('truncated').text)
        obj_struct['difficult'] = int(obj.find('difficult').text)
        bbox = obj.find('bndbox')
        obj_struct['bbox'] = [int(bbox.find('xmin').text),
                              int(bbox.find('ymin').text),
                              int(bbox.find('xmax').text),
                              int(bbox.find('ymax').text)]
        objects.append(obj_struct)

    return objects


def voc_ap(rec, prec, use_07_metric=False):
    """
    ap = voc_ap(rec, prec, [use_07_metric])
    Compute VOC AP given precision and recall.
    If use_07_metric is true, uses the
    VOC 07 11 point method (default:False).
    """
    if use_07_metric:
        # 11 point metric
        ap = 0.
        for t in np.arange(0., 1.1, 0.1):
            if np.sum(rec >= t) == 0:
                p = 0
            else:
                p = np.max(prec[rec >= t])
            ap = ap + p / 11.
    else:
        # correct AP calculation
        # first append sentinel values at the end
        mrec = np.concatenate(([0.], rec, [1.]))
        mpre = np.concatenate(([0.], prec, [0.]))

        # compute the precision envelope
        for i in range(mpre.size - 1, 0, -1):
            mpre[i - 1] = np.maximum(mpre[i - 1], mpre[i])

        # to calculate area under PR curve, look for points
        # where X axis (recall) changes value
        i = np.where(mrec[1:] != mrec[:-1])[0]

        # and sum (\Delta recall) * prec
        ap = np.sum((mrec[i + 1] - mrec[i]) * mpre[i + 1])
    return ap


def voc_eval(detpath,
             annopath,
             imagesetfile,
             classname,
             cachedir,
             ovthresh=0.5,
             use_07_metric=False):
    """rec, prec, ap = voc_eval(detpath,
                                annopath,
                                imagesetfile,
                                classname,
                                [ovthresh],
                                [use_07_metric])

    Top level function that does the PASCAL VOC evaluation.

    detpath: Path to detections
        detpath.format(classname) should produce the detection results file.
    annopath: Path to annotations
        annopath.format(imagename) should be the xml annotations file.
    imagesetfile: Text file containing the list of images, one image per line.
    classname: Category name (duh)
    cachedir: Directory for caching the annotations
    [ovthresh]: Overlap threshold (default = 0.5)
    [use_07_metric]: Whether to use VOC07's 11 point AP computation
        (default False)
    """
    # assumes detections are in detpath.format(classname)
    # assumes annotations are in annopath.format(imagename)
    # assumes imagesetfile is a text file with each line an image name
    # cachedir caches the annotations in a pickle file

    # first load gt
    if not os.path.isdir(cachedir):
        os.mkdir(cachedir)
    cachefile = os.path.join(cachedir, 'annots.pkl')
    # read list of images
    with open(imagesetfile, 'r') as f:
        lines = f.readlines()
    imagenames = [x.strip() for x in lines]


    if not os.path.isfile(cachefile):
        # load annots
        recs = {}
        for i, imagename in enumerate(imagenames):
            recs[imagename] = parse_rec(annopath.format(imagename))
            if i % 100 == 0:
                print('Reading annotation for {:d}/{:d}'.format(
                    i + 1, len(imagenames)))
        # save
        print('Saving cached annotations to {:s}'.format(cachefile))
        with open(cachefile, 'wb') as f:
            pickle.dump(recs, f)
    else:
        # load
        with open(cachefile, 'rb') as f:
            recs = pickle.load(f)

    # extract gt objects for this class
    class_recs = {}
    npos = 0
    for imagename in imagenames:
        R = [obj for obj in recs[imagename] if obj['name'] == classname]
        bbox = np.array([x['bbox'] for x in R])
        difficult = np.array([x['difficult'] for x in R]).astype(bool)
        det = [False] * len(R)
        npos = npos + sum(~difficult)
        class_recs[imagename] = {'bbox': bbox,
                                 'difficult': difficult,
                                 'det': det}

    # read dets
    detfile = detpath.format(classname)
    with open(detfile, 'r') as f:
        lines = f.readlines()
    #print('----lines={}'.format(lines))
    # using "__" instead of " " because the data path under Google drive is all "/content/drive/MyDrive/...
    # Therefore, the following .split(' ') function would result in error
    #splitlines = [x.strip().split('__') for x in lines]
    splitlines = [x.strip().split(' ') for x in lines]
    image_ids = [x[0] for x in splitlines]
    confidence = np.array([float(x[1]) for x in splitlines])
    BB = np.array([[float(z) for z in x[2:]] for x in splitlines])
    #print('----BB={}'.format(BB))
    # sort by confidence
    sorted_ind = np.argsort(-confidence)
    sorted_scores = np.sort(-confidence)
    BB = BB[sorted_ind, :]
    image_ids = [image_ids[x] for x in sorted_ind]

    # go down dets and mark TPs and FPs
    nd = len(image_ids)
    tp = np.zeros(nd)
    fp = np.zeros(nd)
    for d in range(nd):
        R = class_recs[image_ids[d]]
        bb = BB[d, :].astype(float)
        ovmax = -np.inf
        BBGT = R['bbox'].astype(float)

        if BBGT.size > 0:
            # compute overlaps
            # intersection
            ixmin = np.maximum(BBGT[:, 0], bb[0])
            iymin = np.maximum(BBGT[:, 1], bb[1])
            ixmax = np.minimum(BBGT[:, 2], bb[2])
            iymax = np.minimum(BBGT[:, 3], bb[3])
            iw = np.maximum(ixmax - ixmin + 1., 0.)
            ih = np.maximum(iymax - iymin + 1., 0.)
            inters = iw * ih

            # union
            uni = ((bb[2] - bb[0] + 1.) * (bb[3] - bb[1] + 1.) +
                   (BBGT[:, 2] - BBGT[:, 0] + 1.) *
                   (BBGT[:, 3] - BBGT[:, 1] + 1.) - inters)

            overlaps = inters / uni
            ovmax = np.max(overlaps)
            jmax = np.argmax(overlaps)

        if ovmax > ovthresh:
            if not R['difficult'][jmax]:
                if not R['det'][jmax]:
                    tp[d] = 1.
                    R['det'][jmax] = 1
                else:
                    fp[d] = 1.
        else:
            fp[d] = 1.

    # compute precision recall
    fp = np.cumsum(fp)
    tp = np.cumsum(tp)
    rec = tp / float(npos)
    # avoid divide by zero in case the first detection matches a difficult
    # ground truth
    prec = tp / np.maximum(tp + fp, np.finfo(np.float64).eps)
    ap = voc_ap(rec, prec, use_07_metric)

    return rec, prec, ap

def _do_python_eval_quite(res_prefix,_devkit_path ,output_dir=''):
    # do remind only PAScal VOC 07 test needs to use use_07_metric ==  True
    # simply replace 2007 with year bigger than 2010 will work
    _year = '2007'
    _classes = ('__background__',  # always index 0
                'aeroplane', 'bicycle', 'bird', 'boat',
                'bottle', 'bus', 'car', 'cat', 'chair',
                'cow', 'diningtable', 'dog', 'horse',
                'motorbike', 'person', 'pottedplant',
                'sheep', 'sofa', 'train', 'tvmonitor')
    filename = res_prefix + '{:s}.txt'
    # annopath indicates where xml files are
    annopath = os.path.join(
        _devkit_path,
        'VOCdevkit',
        'VOC' + _year,
        'Annotations',
        '{:s}.xml')
    # imagesetfile indicates where test.txt (testing list) is
    imagesetfile = os.path.join(
        _devkit_path,
        'VOCdevkit',
        'VOC' + _year,
        'ImageSets',
        'Main',
        'test.txt') # test.txt
    # cachedir = os.path.join(_devkit_path, 'annotations_cache') # revised by Alex
    # cachedir indicates where annots.pkl is!
    cachedir = GT_temp_folder
    aps = []

    result = dict()
    # The PASCAL VOC metric changed in 2010
    use_07_metric = True if int(_year) < 2010 else False
    # print('VOC07 metric? ' + ('Yes' if use_07_metric else 'No'))
    if not os.path.isdir(output_dir):
        os.mkdir(output_dir)

    print("Begin to perform mAP estimation")
    for i, cls in enumerate(_classes):
        if cls == '__background__':
            continue

        rec, prec, ap = voc_eval(
            filename, annopath, imagesetfile, cls, cachedir, ovthresh=0.5,
            use_07_metric=use_07_metric)
        aps += [ap]
        # print('AP for {} = {:.4f}'.format(cls, ap))
        result[cls] = ap
        # the following file (rec, prec, & ap of each class) is only for back-up.
        with open(os.path.join(output_dir, cls + '_pr.pkl'), 'wb') as f:
            pickle.dump({'rec': rec, 'prec': prec, 'ap': ap}, f)

    return result


def test_result(model, prefix, VOC_root_dir, outfile, test_list):
    class_num = cls_num
    #list_file = 'VOC2007_test.txt'

    dataset = VOCDatasets(transform,test_list, VOC_root_dir,None, False)

    test_loader = data.DataLoader(dataset=dataset,
                                  batch_size=1,
                                  shuffle=False,
                                  num_workers=2)

    test_loader = tqdm(test_loader)

    #list_file = test_list
    lines = []
    with open(test_list) as f:
        lines = f.readlines()

    fps = [0] * class_num
    if not os.path.exists(outfile):
        os.mkdir(outfile)
    for i in range(class_num):
        buf = '%s/%s%s.txt' % (prefix, outfile, classes[i])
        fps[i] = open(buf, 'w')

    # do remember that label (of testing data) is not used in the following for-loop
    # the detection results stored in txt files will be evaluated in _do_python_eval_quite() by reading xml files.
    for lineId, (images, label) in enumerate(test_loader):
        t1 = time.time()
        #img = cv2.imread(lines[lineId].split(" ")[0])
        img = cv2.imread(VOC_root_dir + lines[lineId].split("__")[0])
        width, height = img.shape[1], img.shape[0]

        images = images.cuda()

        t2 = time.time()
        #print("load times: ",t2-t1)

        t1 = time.time()
        pred = model(images)
        t2 = time.time()
        #print("pred times: ",t2-t1)

        t1 = time.time()
        pred_boxes,pred_conf = yolo_box_decoder(pred)
        t2 = time.time()
        #print("decoder times: ",t2-t1)

        fileId = os.path.basename(lines[lineId]).split('.')[0]

        for j in range(len(pred_boxes)):

            x1 = pred_boxes[j,0]
            y1 = pred_boxes[j,1]
            x2 = x1 + pred_boxes[j,2]
            y2 = y1 + pred_boxes[j,3]

            x1,x2 = x1*width,x2*width
            y1,y2 = y1*height,y2*height

            cls_id = int(pred_conf[j,0])
            scores = pred_conf[j,1]
            #print(scores)
            fps[cls_id].write('%s %.3f %.1f %.1f %.1f %.1f\n' %
                              (fileId, scores, x1 + 1, y1 + 1, x2 + 1, y2 + 1))

            ## uncomment the following section to produce detection results of the current epoch
            '''
            if scores > 0.2:
                cv2.rectangle(img,(int(x1),int(y1)-20),(int(x2),int(y1)),(125,125,125),-1)
                img = cv2.putText(img, classes[cls_id] + ': %.2f' % round(scores,3), (int(x1),int(y1)),  cv2.FONT_HERSHEY_PLAIN, 1.5, (0,0,0), thickness=1)
                #img = cv2.putText(img, str(round(scores,3)), (int(x1),int(y1)+20),  cv2.FONT_HERSHEY_PLAIN, 2.0, (0,0,0), thickness=1)
                img = cv2.rectangle(img, (int(x1),int(y1)), (int(x2),int(y2)), (0, 255, 0), 2)
                filename = lines[lineId].split(" ")[0]
                filename_only = filename.split("/")[-1]
                cv2.imwrite('/content/drive/MyDrive/YOLO_data_model/voc07_det_results/' + filename_only, img)
            '''

    for i in range(class_num):
        fps[i].close()

    return

def eval_mAp(model, prefix, VOC_root_dir, outfile, test_list):
    # prefix = /content/drive/MyDrive/YOLO_data_model/detection_temp_folder
    # outfile = VOC
    # res_prefix is result temp folder
    res_prefix = prefix + '/' + outfile # /content/drive/MyDrive/YOLO_data_model/detection_temp_folder/VOC and the detection file will be VOCCar.txt, VOCTruck.txt etc,.
    # test_list = "/content/drive/MyDrive/YOLO_data_model/VOC2007_test_toy_example.txt"
    # perform inference for every test file
    test_result(model, prefix, VOC_root_dir, outfile, test_list)
    # output_dir is the folder to put GT pkl files and GT_temp_folder = /content/drive/MyDrive/YOLO_data_model/GT_temp_folder
    # VOC_root_dir = "/content/drive/MyDrive/YOLO_data_model/VOCdevkit"
    result = _do_python_eval_quite(res_prefix, VOC_root_dir ,output_dir = GT_temp_folder)

    return result

# %%
## training codes:

best_score = 0
eval_score = 0


for epoch in range(epochs_start, epochs_end):
    epoch_loss = 0
    train_iterator = tqdm(train_loader, ncols=30)
    mulit_batch_ = 0
    #print("epoch={}".format(epoch))
    # if epoch == 0:
    #     learning_rate = lr/10 # lr = 0.1e-3
    # elif epoch >= 1 and epoch <=5:
    #     learning_rate = 0.2e-3/10
    # elif epoch <= 10:
    #     learning_rate = 0.2e-3/10
    # elif epoch <= 30:
    #     learning_rate= 0.0001/10
    # elif epoch <= 40:
    #     learning_rate=0.00001
    # else:
    #     learning_rate=0.00001

    #因為我將epoch的數量改小了，所以lr也去做了修改，不然沒有任何作用
    #在目前程式碼的條件下，起始值影響不太大
    learning_rate = lr/10
    # if epoch == 0:
    #     learning_rate = lr/10 # lr = 0.1e-3
    # elif epoch >= 1 and epoch <=2:
    #     learning_rate = lr/10
    # elif epoch <= 3:
    #     learning_rate = 2e-5
    # elif epoch <= 5:
    #     learning_rate= 1e-5
    # elif epoch <= 7:
    #     learning_rate= 1e-5
    # else:
    #     learning_rate= 1e-5

    for param_group in optimizer.param_groups:
        param_group['lr'] = learning_rate

    for train_batch, (images, target) in enumerate(train_iterator):
        print('--------------------------train_batch={}'.format(train_batch))

        images = images.cuda()

        pred = net(images)

        loss_xx, loss_info = loss_detect(pred, target)

        assert not np.isnan\
            (loss_xx.data.cpu().numpy())

        epoch_loss += loss_xx

        status = '[{0}] lr = {1} batch_loss = {2:.3f} epoch_loss = {3:.3f} '.format(
            epoch, learning_rate, loss_xx.data, epoch_loss.data / (train_batch + 1))



        train_iterator.set_description(status)

        loss_xx.backward()

        optimizer.step()
        optimizer.zero_grad()
        step += 1

    if epoch % 1 == 0: # and epoch > 5:
        print("Evaluate~~~~~   ")
        net.eval()
        result = eval_mAp(net, detection_result_txt_folder, VOC_root_dir,'voc', eval_image_list)
        eval_score = np.mean(list(result.values()))

        net.train()

        if best_score < eval_score:
            best_score = eval_score
            torch.save(net.state_dict(), model_path + "best_.pkl")
        mAP_string = "mean ap : {:.3f} , best ap: {:.3f}".format(eval_score, best_score)
        print(mAP_string)

        with open(savelog_filename, 'a') as f:
            print('%s %s' % (time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()), mAP_string), file=f)

    torch.save(net.state_dict(), model_path + "model_.pkl")

print(best_score)
# Out:
#   0%| | 0/209 [00:00<?, ?it/s]<ipython-input-38-812f1de43a34>:119: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at ../aten/src/ATen/native/IndexingUtils.h:27.)
#   obj_axis_pred = obj_loc_pred[coo_response_mask].view(-1, 4)
# <ipython-input-38-812f1de43a34>:120: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at ../aten/src/ATen/native/IndexingUtils.h:27.)
#   obj_axis_target = obj_loc_target[coo_response_mask].view(-1, 4)
# <ipython-input-38-812f1de43a34>:124: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at ../aten/src/ATen/native/IndexingUtils.h:27.)
#   obj_response_pred = obj_contain_pred[iou_response_mask].view(-1)
# <ipython-input-38-812f1de43a34>:125: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at ../aten/src/ATen/native/IndexingUtils.h:27.)
#   obj_response_target = obj_contain_target[iou_response_mask].view(-1)
# /usr/local/lib/python3.11/dist-packages/torch/nn/_reduction.py:51: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# [1] lr = 0.0001 batch_loss = 2
# --------------------------train_batch=0
# /usr/local/lib/python3.11/dist-packages/torch/autograd/graph.py:825: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at ../aten/src/ATen/native/IndexingUtils.h:27.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [1] lr = 0.0001 batch_loss = 2
# --------------------------train_batch=1
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=2
# --------------------------train_batch=3
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=4
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=5
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=6
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=7
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=8
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=9
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=10
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=11
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=12
# [1] lr = 0.0001 batch_loss = 8
# --------------------------train_batch=13
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=14
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=15
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=16
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=17
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=18
# [1] lr = 0.0001 batch_loss = 9
# --------------------------train_batch=19
# [1] lr = 0.0001 batch_loss = 8
# --------------------------train_batch=20
# [1] lr = 0.0001 batch_loss = 9
# --------------------------train_batch=21
# [1] lr = 0.0001 batch_loss = 9
# --------------------------train_batch=22
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=23
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=24
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=25
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=26
# [1] lr = 0.0001 batch_loss = 8
# --------------------------train_batch=27
# [1] lr = 0.0001 batch_loss = 9
# --------------------------train_batch=28
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=29
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=30
# [1] lr = 0.0001 batch_loss = 8
# --------------------------train_batch=31
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=32
# [1] lr = 0.0001 batch_loss = 8
# --------------------------train_batch=33
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=34
# --------------------------train_batch=35
# [1] lr = 0.0001 batch_loss = 9
# --------------------------train_batch=36
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=37
# [1] lr = 0.0001 batch_loss = 8
# --------------------------train_batch=38
# [1] lr = 0.0001 batch_loss = 8
# --------------------------train_batch=39
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=40
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=41
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=42
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=43
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=44
# [1] lr = 0.0001 batch_loss = 8
# --------------------------train_batch=45
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=46
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=47
# [1] lr = 0.0001 batch_loss = 8
# --------------------------train_batch=48
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=49
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=50
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=51
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=52
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=53
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=54
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=55
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=56
# [1] lr = 0.0001 batch_loss = 8
# --------------------------train_batch=57
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=58
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=59
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=60
# [1] lr = 0.0001 batch_loss = 8
# --------------------------train_batch=61
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=62
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=63
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=64
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=65
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=66
# [1] lr = 0.0001 batch_loss = 9
# --------------------------train_batch=67
# [1] lr = 0.0001 batch_loss = 8
# --------------------------train_batch=68
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=69
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=70
# [1] lr = 0.0001 batch_loss = 9
# --------------------------train_batch=71
# [1] lr = 0.0001 batch_loss = 8
# --------------------------train_batch=72
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=73
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=74
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=75
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=76
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=77
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=78
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=79
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=80
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=81
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=82
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=83
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=84
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=85
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=86
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=87
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=88
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=89
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=90
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=91
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=92
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=93
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=94
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=95
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=96
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=97
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=98
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=99
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=100
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=101
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=102
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=103
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=104
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=105
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=106
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=107
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=108
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=109
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=110
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=111
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=112
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=113
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=114
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=115
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=116
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=117
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=118
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=119
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=120
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=121
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=122
# [1] lr = 0.0001 batch_loss = 1
# --------------------------train_batch=123
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=124
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=125
# [1] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=126
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=127
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=128
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=129
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=130
# [1] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=131
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=132
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=133
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=134
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=135
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=136
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=137
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=138
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=139
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=140
# [1] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=141
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=142
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=143
# --------------------------train_batch=144
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=145
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=146
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=147
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=148
# [1] lr = 0.0001 batch_loss = 9
# --------------------------train_batch=149
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=150
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=151
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=152
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=153
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=154
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=155
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=156
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=157
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=158
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=159
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=160
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=161
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=162
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=163
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=164
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=165
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=166
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=167
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=168
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=169
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=170
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=171
# [1] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=172
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=173
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=174
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=175
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=176
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=177
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=178
# [1] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=179
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=180
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=181
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=182
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=183
# --------------------------train_batch=184
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=185
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=186
# [1] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=187
# [1] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=188
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=189
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=190
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=191
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=192
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=193
# [1] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=194
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=195
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=196
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=197
# [1] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=198
# [1] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=199
# [1] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=200
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=201
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=202
# [1] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=203
# [1] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=204
# [1] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=205
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=206
# [1] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=207
# [1] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=208
# [1] lr = 0.0001 batch_loss = 7
# Evaluate~~~~~
#   0%|          | 0/4952 [00:00<?, ?it/s]<ipython-input-36-efe9366e620c>:100: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at ../aten/src/ATen/native/IndexingUtils.h:27.)
#   bbox = pred_bboxes[mask_box].data
# 100%|██████████| 4952/4952 [02:37<00:00, 31.41it/s]
# Begin to perform mAP estimation
# mean ap : 0.010 , best ap: 0.010
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=0
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=1
# --------------------------train_batch=2
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=3
# [2] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=4
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=5
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=6
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=7
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=8
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=9
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=10
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=11
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=12
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=13
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=14
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=15
# [2] lr = 0.0001 batch_loss = 9
# --------------------------train_batch=16
# [2] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=17
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=18
# [2] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=19
# [2] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=20
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=21
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=22
# [2] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=23
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=24
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=25
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=26
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=27
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=28
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=29
# [2] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=30
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=31
# [2] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=32
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=33
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=34
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=35
# [2] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=36
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=37
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=38
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=39
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=40
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=41
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=42
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=43
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=44
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=45
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=46
# [2] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=47
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=48
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=49
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=50
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=51
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=52
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=53
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=54
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=55
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=56
# [2] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=57
# --------------------------train_batch=58
# [2] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=59
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=60
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=61
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=62
# --------------------------train_batch=63
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=64
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=65
# [2] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=66
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=67
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=68
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=69
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=70
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=71
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=72
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=73
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=74
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=75
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=76
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=77
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=78
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=79
# [2] lr = 0.0001 batch_loss = 2
# --------------------------train_batch=80
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=81
# [2] lr = 0.0001 batch_loss = 2
# --------------------------train_batch=82
# [2] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=83
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=84
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=85
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=86
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=87
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=88
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=89
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=90
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=91
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=92
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=93
# [2] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=94
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=95
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=96
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=97
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=98
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=99
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=100
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=101
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=102
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=103
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=104
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=105
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=106
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=107
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=108
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=109
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=110
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=111
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=112
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=113
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=114
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=115
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=116
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=117
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=118
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=119
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=120
# [2] lr = 0.0001 batch_loss = 2
# --------------------------train_batch=121
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=122
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=123
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=124
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=125
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=126
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=127
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=128
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=129
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=130
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=131
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=132
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=133
# [2] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=134
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=135
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=136
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=137
# [2] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=138
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=139
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=140
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=141
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=142
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=143
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=144
# [2] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=145
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=146
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=147
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=148
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=149
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=150
# [2] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=151
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=152
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=153
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=154
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=155
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=156
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=157
# [2] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=158
# [2] lr = 0.0001 batch_loss = 2
# --------------------------train_batch=159
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=160
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=161
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=162
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=163
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=164
# [2] lr = 0.0001 batch_loss = 8
# --------------------------train_batch=165
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=166
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=167
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=168
# [2] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=169
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=170
# [2] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=171
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=172
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=173
# [2] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=174
# [2] lr = 0.0001 batch_loss = 2
# --------------------------train_batch=175
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=176
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=177
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=178
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=179
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=180
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=181
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=182
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=183
# --------------------------train_batch=184
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=185
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=186
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=187
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=188
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=189
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=190
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=191
# [2] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=192
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=193
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=194
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=195
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=196
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=197
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=198
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=199
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=200
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=201
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=202
# [2] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=203
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=204
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=205
# [2] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=206
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=207
# [2] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=208
# [2] lr = 0.0001 batch_loss = 2
# Evaluate~~~~~
# 100%|██████████| 4952/4952 [02:30<00:00, 33.00it/s]
# Begin to perform mAP estimation
# mean ap : 0.041 , best ap: 0.041
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=0
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=1
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=2
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=3
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=4
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=5
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=6
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=7
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=8
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=9
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=10
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=11
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=12
# [3] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=13
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=14
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=15
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=16
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=17
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=18
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=19
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=20
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=21
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=22
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=23
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=24
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=25
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=26
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=27
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=28
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=29
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=30
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=31
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=32
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=33
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=34
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=35
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=36
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=37
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=38
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=39
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=40
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=41
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=42
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=43
# [3] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=44
# [3] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=45
# [3] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=46
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=47
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=48
# [3] lr = 0.0001 batch_loss = 2
# --------------------------train_batch=49
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=50
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=51
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=52
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=53
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=54
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=55
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=56
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=57
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=58
# [3] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=59
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=60
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=61
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=62
# [3] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=63
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=64
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=65
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=66
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=67
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=68
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=69
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=70
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=71
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=72
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=73
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=74
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=75
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=76
# [3] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=77
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=78
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=79
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=80
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=81
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=82
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=83
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=84
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=85
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=86
# --------------------------train_batch=87
# [3] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=88
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=89
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=90
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=91
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=92
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=93
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=94
# [3] lr = 0.0001 batch_loss = 2
# --------------------------train_batch=95
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=96
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=97
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=98
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=99
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=100
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=101
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=102
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=103
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=104
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=105
# [3] lr = 0.0001 batch_loss = 2
# --------------------------train_batch=106
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=107
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=108
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=109
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=110
# [3] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=111
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=112
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=113
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=114
# [3] lr = 0.0001 batch_loss = 7
# --------------------------train_batch=115
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=116
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=117
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=118
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=119
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=120
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=121
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=122
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=123
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=124
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=125
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=126
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=127
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=128
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=129
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=130
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=131
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=132
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=133
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=134
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=135
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=136
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=137
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=138
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=139
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=140
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=141
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=142
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=143
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=144
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=145
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=146
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=147
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=148
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=149
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=150
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=151
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=152
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=153
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=154
# [3] lr = 0.0001 batch_loss = 2
# --------------------------train_batch=155
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=156
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=157
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=158
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=159
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=160
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=161
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=162
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=163
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=164
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=165
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=166
# --------------------------train_batch=167
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=168
# [3] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=169
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=170
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=171
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=172
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=173
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=174
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=175
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=176
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=177
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=178
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=179
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=180
# [3] lr = 0.0001 batch_loss = 2
# --------------------------train_batch=181
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=182
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=183
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=184
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=185
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=186
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=187
# [3] lr = 0.0001 batch_loss = 2
# --------------------------train_batch=188
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=189
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=190
# [3] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=191
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=192
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=193
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=194
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=195
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=196
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=197
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=198
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=199
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=200
# [3] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=201
# [3] lr = 0.0001 batch_loss = 6
# --------------------------train_batch=202
# [3] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=203
# [3] lr = 0.0001 batch_loss = 2
# --------------------------train_batch=204
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=205
# [3] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=206
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=207
# [3] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=208
# [3] lr = 0.0001 batch_loss = 6
# Evaluate~~~~~
# 100%|██████████| 4952/4952 [02:31<00:00, 32.58it/s]
# Begin to perform mAP estimation
# mean ap : 0.034 , best ap: 0.041
# [4] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=0
# --------------------------train_batch=1
# [4] lr = 0.0001 batch_loss = 4
# --------------------------train_batch=2
# [4] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=3
# [4] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=4
# [4] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=5
# ...
# [9] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=197
# [9] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=198
# [9] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=199
# [9] lr = 0.0001 batch_loss = 5
# --------------------------train_batch=200
# [9] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=201
# [9] lr = 0.0001 batch_loss = 2
# --------------------------train_batch=202
# [9] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=203
# [9] lr = 0.0001 batch_loss = 2
# --------------------------train_batch=204
# [9] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=205
# [9] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=206
# [9] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=207
# [9] lr = 0.0001 batch_loss = 3
# --------------------------train_batch=208
# [9] lr = 0.0001 batch_loss = 4
# Evaluate~~~~~
# 100%|██████████| 4952/4952 [02:37<00:00, 31.39it/s]
# Begin to perform mAP estimation
# mean ap : 0.122 , best ap: 0.122
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=0
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=1
# --------------------------train_batch=2
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=3
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=4
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=5
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=6
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=7
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=8
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=9
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=10
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=11
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=12
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=13
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=14
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=15
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=16
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=17
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=18
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=19
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=20
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=21
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=22
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=23
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=24
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=25
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=26
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=27
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=28
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=29
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=30
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=31
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=32
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=33
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=34
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=35
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=36
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=37
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=38
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=39
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=40
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=41
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=42
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=43
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=44
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=45
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=46
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=47
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=48
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=49
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=50
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=51
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=52
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=53
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=54
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=55
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=56
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=57
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=58
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=59
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=60
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=61
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=62
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=63
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=64
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=65
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=66
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=67
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=68
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=69
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=70
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=71
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=72
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=73
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=74
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=75
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=76
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=77
# --------------------------train_batch=78
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=79
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=80
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=81
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=82
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=83
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=84
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=85
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=86
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=87
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=88
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=89
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=90
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=91
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=92
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=93
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=94
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=95
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=96
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=97
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=98
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=99
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=100
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=101
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=102
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=103
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=104
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=105
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=106
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=107
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=108
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=109
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=110
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=111
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=112
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=113
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=114
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=115
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=116
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=117
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=118
# --------------------------train_batch=119
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=120
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=121
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=122
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=123
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=124
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=125
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=126
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=127
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=128
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=129
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=130
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=131
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=132
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=133
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=134
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=135
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=136
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=137
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=138
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=139
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=140
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=141
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=142
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=143
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=144
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=145
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=146
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=147
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=148
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=149
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=150
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=151
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=152
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=153
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=154
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=155
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=156
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=157
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=158
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=159
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=160
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=161
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=162
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=163
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=164
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=165
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=166
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=167
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=168
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=169
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=170
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=171
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=172
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=173
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=174
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=175
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=176
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=177
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=178
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=179
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=180
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=181
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=182
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=183
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=184
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=185
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=186
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=187
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=188
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=189
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=190
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=191
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=192
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=193
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=194
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=195
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=196
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=197
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=198
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=199
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=200
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=201
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=202
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=203
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=204
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=205
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=206
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=207
# [10] lr = 0.0001 batch_loss =
# --------------------------train_batch=208
# [10] lr = 0.0001 batch_loss =
# Evaluate~~~~~
#  75%|███████▍  | 3710/4952 [01:58<00:53, 23.26it/s]

# %%
  #  Let's try to perform inference for single image

def predict_gpu(model,image_name):

    image = cv2.imread(image_name)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    h,w,_ = image.shape
    img = cv2.resize(image,(448,448))

    # Do remember that the following transform only accepts input to be numpy array instead PIL image
    # Therefore, the previously-defined transfroms() can't be used here
    transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize([0.485, 0.456, 0.406], [1, 1, 1])])
    # image is an torch tensor
    img = transform(img)*255
    #  None = NP.newaxis and the reason why doing this is that model inference would only accept 4-d torch tensor.
    img = Variable(img[None,:,:,:])
    img = img.cuda()

    pred= model(img)
    # detection_classses contains object id and its confidence
    boxes, detection_classses = yolo_box_decoder(pred,conf_thresh=0.1,nms_thresh=0.5) #threshold=0.1

    return boxes,detection_classses

def plot_boxes_cv2(img, boxes, detection_classses, class_names=None, color=None):

    width = img.shape[1]
    height = img.shape[0]

    for j in range(len(boxes)):

        x1 = boxes[j,0]
        y1 = boxes[j,1]
        x2 = x1 + boxes[j,2]
        y2 = y1 + boxes[j,3]
        x1,x2 = int(x1*width),int(x2*width)
        y1,y2 = int(y1*height),int(y2*height)

        cls_id = int(detection_classses[j,0])
        prob = float(detection_classses[j,1])
        print(prob)

        img = cv2.putText(img, class_names[cls_id], (x1,y1),  cv2.FONT_HERSHEY_PLAIN, 1.0, (0,0,255), thickness=1)
        img = cv2.putText(img, str(round(prob,3)), (x1,y1+20),  cv2.FONT_HERSHEY_PLAIN, 1.0, (0,0,255), thickness=1)
        img = cv2.rectangle(img, (x1,y1), (x2,y2), (0, 0, 255), 2)

    return img

model = YOLO(cls_num, bbox_num, box_scale)
model.eval()
# 1. load your best model trained so far.
model.load_state_dict(torch.load( model_path + 'best_.pkl'))
# 2. load example model trained for only a few epochs
# model.load_state_dict(torch.load( model_path + 'example_model_mAP14.1.pkl'))
# model.load_state_dict(torch.load( model_path + 'best_mAP33.6.pkl'))

'''
torch.load(),這部分是用來載入儲存在檔案中的模型權重
model.load_state_dict(),用來將已載入的權重套用到模型 model 上。
'''


model.cuda()

# testing image
image_name = VOC_root_dir + "VOCdevkit/VOC2007/JPEGImages/000001.jpg"
#image_name = VOC_root_dir + "testing_imgs/car_only.jpg"
#image_name = VOC_root_dir + "testing_imgs/beauty_only.jpg"
#image_name = VOC_root_dir + "testing_imgs/car_n_beauty.jpg"

image = cv2.imread(image_name)
# performing inference
boxes, detection_classses = predict_gpu(model,image_name)
# overlapping detection bounding box
image = plot_boxes_cv2(image, boxes, detection_classses, class_names = classes, color=None)

cv2_imshow(image)
